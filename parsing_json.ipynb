# %% [markdown]
# # Let's make Wordcloud Video Bookmark, Part 1

# %% [markdown]
# # Preliminaries - - ------ ☆

# %%
import json

# %%
from __future__ import print_function  # For version compatibility python v2 & v3.You want to delete this cell if you use python version 3  
import sys, os, time
for x in range(0,10):
  print(x, sep=' ', end='')
# Out:
# 0123456789

# %% [markdown]
# ## 데이터 로드, 그리고 예쁘게 뽑기

# %%
with open('nobel_speech.json') as json_file:
    data = json.load(json_file)

# %%
preetydata=json.dumps(data,indent=4)
print(preetydata)
# Out:
# {
#     "userName": "",
#     "isOwned": true,
#     "description": null,
#     "isEditable": true,
#     "created": "2019-04-08T16:29:00.1408465+00:00",
#     "partition": null,
#     "summarizedInsights": {
#         "statistics": {
#             "correspondenceCount": 0,
#             "speakerTalkToListenRatio": {
#                 "1": 1
#             },
#             "speakerWordCount": {
#                 "1": 4330
#             },
#             "speakerNumberOfFragments": {
#                 "1": 1
#             },
#             "speakerLongestMonolog": {
#                 "1": 2160
#             }
#         },
#         "name": "nobel-peace-speech",
#         "audioEffects": [],
#         "topics": [
#             {
#                 "confidence": 0.907,
#                 "name": "Politics and Government/Foreign Policy",
#                 "appearances": [
#                     {
#                         "endTime": "0:36:00.429",
# ...
